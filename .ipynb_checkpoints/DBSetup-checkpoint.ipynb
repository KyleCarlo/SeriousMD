# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# # Extract

# %% [markdown]
# Read SeriousMD data

# %%
doctors = pd.read_parquet('cleaned/doctors.parquet')
clinics = pd.read_parquet('cleaned/clinics.parquet')
patients = pd.DataFrame()
for i in range(8):
    temp = pd.read_parquet(f"cleaned/px_{i+1}.parquet")
    patients = pd.concat([patients,temp])
appointments = pd.read_parquet('cleaned/appointments.parquet')

# %%
doctors
# Out:
#                                doctorid                  mainspecialty   age
# 0      AD61AB143223EFBC24C7D2583BE69251               general medicine  41.0
# 1      D09BF41544A3365A46C9077EBB5E35C3  family and community medicine  43.0
# 2      FBD7939D674997CDB4692D34DE8633C4                     cardiology  26.0
# 3      28DD2C7955CE926456240B2FF0100BDE            otorhinolaryngology  34.0
# 4      35F4A8D465E6E1EDC05F3D8AB658C551              general dentistry  50.0
# ...                                 ...                            ...   ...
# 60019  CD532DBEF6547A66D2138FAB49AA3B94               general medicine  33.0
# 60020  4473D870B5E31FAA40D2C45E1FF6DC27                           none   NaN
# 60021  A4F554EB2C0934E7FDE2511E8C1573BA                           none   NaN
# 60022  E540A361D93D37A33BB2F55D43DA79D9               general medicine   NaN
# 60023  23BA85862DD19C3550E7C0F0AF84C7ED              internal medicine  38.0
#
# [60024 rows x 3 columns]

# %%
clinics
# Out:
#                                clinicid  \
# 0      77EE3BC58CE560B86C2B59363281E914
# 1      98C39996BF1543E974747A2549B3107C
# 2      9AEADE7BEADA35C83D3B344FBAFE43B0
# 3      FDBD31F2027F20378B1A80125FC862DB
# 4      205C3608ECB984C1F5F5D2F52C934428
# ...                                 ...
# 53957  8DE279A56DBCECE9F9FFC514A7D5A378
# 53958  55A64961C9AA4134016786AE7202682E
# 53959  075E464A7D15E6E5B9D8F8F5B5B16BB9
# 53960  01063BCF7624297FBB408495BCB62904
# 53961  5DA48026B54B6EEB6062817CAA7C30EA
#
#                                 hospitalname  IsHospital      City  \
# 0      St. Luke's Medical Center-Global City        True    Taguig
# 1               Our Lady of Lourdes Hospital        True    Manila
# 2                      Makati Medical Center        True    Makati
# 3             Cardinal Santos Medical Center        True  San Juan
# 4                                       None       False    Burgos
# ...                                      ...         ...       ...
# 53957                                   None       False    Manila
# 53958                                   None       False    Manila
# 53959                                   None       False    Manila
# 53960    Malabon Hospital and Medical Center        True   Malabon
# 53961                                   None       False   Malabon
#
#          Province                     RegionName
# 0          Manila  National Capital Region (NCR)
# 1          Manila  National Capital Region (NCR)
# 2          Manila  National Capital Region (NCR)
# 3          Manila  National Capital Region (NCR)
# 4      Ilocos Sur              Ilocos Region (I)
# ...           ...                            ...
# 53957      Manila  National Capital Region (NCR)
# 53958      Manila  National Capital Region (NCR)
# 53959      Manila  National Capital Region (NCR)
# 53960      Manila  National Capital Region (NCR)
# 53961      Manila  National Capital Region (NCR)
#
# [53962 rows x 6 columns]

# %%
px
# Out:
#                                      pxid    age  gender
# 1        2789C09850D7A504FD0E6BB0B887B119  120.0    MALE
# 2        093B9B81F9965A23B6ABE609615DDFAD  120.0  FEMALE
# 3        AD65691508EE5B6B64EE33F29E5181F9  120.0  FEMALE
# 4        312A4DBFC9997ACAA08AB3F1CD0ED12A  120.0  FEMALE
# 5        0A131D3993E3D802D0118F1AFD0D187F  120.0  FEMALE
# ...                                   ...    ...     ...
# 5512477  E4A2C6A059BD27024843AEA8924ACA01    NaN    MALE
# 5512478  91A193DBF9891D001A11C6ED9093F2F6    NaN  FEMALE
# 5512479  115BB28CFD4701B1E72CA436412D2A34    NaN    MALE
# 5512480  C53E03E6794972AB45656853357AC65A    NaN    MALE
# 5512481  E9AAF10CAF2469FE7BCACB529CC64C45    NaN    MALE
#
# [5512481 rows x 3 columns]

# %%
appt_clinics = appointments.merge(clinics, on='clinicid', how='inner')
appt_city = appt_clinics['City'].value_counts().reset_index()
appt_prov = appt_clinics['Province'].value_counts().reset_index()
appt_city.columns = ['city', 'appt']
appt_prov.columns = ['province', 'appt']

# %%
plt.figure(figsize=(30,6))
plt.bar(x=appt_city['city'], height=appt_city['appt'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(30,6))
plt.bar(x=appt_prov['province'], height=appt_prov['appt'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Read PH Map

# %%
ph_map = gpd.GeoDataFrame.from_file('gadm41_PHL_shp/gadm41_PHL_2.shp')

# %%
ph_map['NAME_2'].unique()
# Out:
# array(['Bangued', 'Boliney', 'Bucay', ..., 'Talusan', 'Titay', 'Tungawan'],
#       dtype=object)

# %%
appt_city
# Out:
#                    city    appt
# 0           Quezon City  144476
# 1                Makati   44079
# 2            Pozzorubio   25187
# 3                Manila   22435
# 4           Iloilo City   17793
# 5   General Santos City   16192
# 6             Cebu City   13204
# 7        Dumaguete City    9184
# 8               Malabon    4833
# 9            Muntinlupa    4828
# 10             San Juan    4398
# 11                Pasig    4388
# 12               Liloan    1944
# 13               Taguig    1466
# 14         Calamba City    1394
# 15               Pangil    1264
# 16            Parañaque    1117
# 17      Santa Rosa City     342
# 18         Malolos City     337
# 19         Dagupan City     287
# 20           Valenzuela     267
# 21               Manito     186
# 22        Olongapo City     112
# 23    San Fernando City      86
# 24          Iligan City      82
# 25             Valencia      81
# 26      Dasmariñas City      64
# 27              Kananga      45
# 28          Bacoor City      32
# 29           Santa Cruz      15
# 30             Makilala      15
# 31          Mandaluyong       4
# 32         Legazpi City       1
# 33            Las Piñas       1
# 34             Siniloan       1

# %% [markdown]
# Merge City and Map

# %%
# match the city names
appt_city.iloc[1, 0] = 'Makati City'
appt_city.iloc[10,0] = 'San Juan - Manila'
# ph_map.iloc[ph_map[(ph_map['NAME_2'] == 'San Juan') & (ph_map['NAME_1'] == 'Metropolitan Manila')].index[0],6] = 'San Juan - Manila'
appt_city.iloc[12,0] = 'Liloan - Cebu'
# ph_map.iloc[ph_map[(ph_map['NAME_2'] == 'Liloan') & (ph_map['NAME_1'] == 'Cebu')].index[0],6] = 'Liloan - Cebu'
appt_city.iloc[23,0] = 'San Fernando City - La Union'
# ph_map.iloc[ph_map[(ph_map['NAME_2'] == 'San Fernando City') & (ph_map['NAME_1'] == 'La Union')].index[0], 6] = 'San Fernando City - La Union'
appt_city.iloc[25,0] = 'Valencia - Negros Oriental'
# ph_map.iloc[ph_map[(ph_map['NAME_2'] == 'Valencia') & (ph_map['NAME_1'] == 'Negros Oriental')].index[0], 6] = 'Valencia - Negros Oriental'
# ph_map.iloc[ph_map[(ph_map['NAME_2'] == 'Dasmariñas')].index[0],6] = 'Dasmariñas City'
# ph_map.iloc[ph_map[(ph_map['NAME_2'] == 'Bacoor')].index[0],6] = 'Bacoor City'
appt_city.iloc[29,0] = 'Santa Cruz - Laguna'
ph_map.iloc[ph_map[(ph_map['NAME_2'] == 'Santa Cruz') & (ph_map['NAME_1'] == 'Laguna')].index[0], 6] = 'Santa Cruz - Laguna'
appt_city
# Out:
#                             city    appt
# 0                    Quezon City  144476
# 1                    Makati City   44079
# 2                     Pozzorubio   25187
# 3                         Manila   22435
# 4                    Iloilo City   17793
# 5            General Santos City   16192
# 6                      Cebu City   13204
# 7                 Dumaguete City    9184
# 8                        Malabon    4833
# 9                     Muntinlupa    4828
# 10             San Juan - Manila    4398
# 11                         Pasig    4388
# 12                 Liloan - Cebu    1944
# 13                        Taguig    1466
# 14                  Calamba City    1394
# 15                        Pangil    1264
# 16                     Parañaque    1117
# 17               Santa Rosa City     342
# 18                  Malolos City     337
# 19                  Dagupan City     287
# 20                    Valenzuela     267
# 21                        Manito     186
# 22                 Olongapo City     112
# 23  San Fernando City - La Union      86
# 24                   Iligan City      82
# 25    Valencia - Negros Oriental      81
# 26               Dasmariñas City      64
# 27                       Kananga      45
# 28                   Bacoor City      32
# 29           Santa Cruz - Laguna      15
# 30                      Makilala      15
# 31                   Mandaluyong       4
# 32                  Legazpi City       1
# 33                     Las Piñas       1
# 34                      Siniloan       1

# %%
# check if all city names equal
for city in list(appt_city['city']):
    if len(ph_map[[True if city in each else False for each in ph_map['NAME_2']]]) != 1:
        print(city)
# Out:
# Manila

# %%
df_map = ph_map[['NAME_1','NAME_2','geometry']]
df_map.columns = ['province', 'city', 'geometry']

# %%
regions = {
    'Luzon': [  
        'Abra',
        'Albay',
        'Apayao',
        'Aurora',
        'Bataan',
        'Batanes',
        'Batangas',
        'Benguet',
        'Bulacan',
        'Cagayan',
        'Camarines Norte',
        'Camarines Sur',
        'Catanduanes',
        'Cavite',
        'Ifugao',
        'Ilocos Norte',
        'Ilocos Sur',
        'Isabela',
        'Kalinga',
        'La Union',
        'Laguna',
        'Marinduque',
        'Masbate',
        'Mountain Province',
        'Nueva Ecija',
        'Nueva Vizcaya',
        'Occidental Mindoro',
        'Oriental Mindoro',
        'Palawan',
        'Pampanga',
        'Pangasinan',
        'Quezon',
        'Quirino',
        'Rizal',
        'Romblon',
        'Sorsogon',
        'Tarlac',
        'Zambales',
        'Metropolitan Manila'
    ],
    'Visayas': [
        'Aklan',
        'Antique',
        'Biliran',
        'Bohol',
        'Capiz',
        'Cebu',
        'Eastern Samar',
        'Guimaras',
        'Iloilo',
        'Leyte',
        'Negros Occidental',
        'Negros Oriental',
        'Northern Samar',
        'Samar',
        'Siquijor',
        'Southern Leyte'
    ],
    'Mindanao': [
        'Agusan del Norte',
        'Agusan del Sur',
        'Basilan',
        'Bukidnon',
        'Camiguin',
        'Cotabato',
        'Compostela Valley',
        'Davao del Norte',
        'Davao del Sur',
        'Davao Occidental',
        'Davao Oriental',
        'Dinagat Islands',
        'Lanao del Norte',
        'Lanao del Sur',
        'Maguindanao',
        'Misamis Occidental',
        'Misamis Oriental',
        'Sarangani',
        'North Cotabato',
        'South Cotabato',
        'Sultan Kudarat',
        'Sulu',
        'Surigao del Norte',
        'Surigao del Sur',
        'Tawi-Tawi',
        'Zamboanga del Norte',
        'Zamboanga del Sur',
        'Zamboanga Sibugay'
    ]
}

# %%
#   North Luzon Agribusiness Quadrangle
#   Metro Luzon Urban Beltway
#   Central Philippines
#   Mindanao
super_regions = {
    'NLAQ':[
        'Ilocos Norte',
        'Ilocos Sur',
        'La Union',
        'Pangasinan',
        'Abra',
        'Apayao',
        'Benguet',
        'Ifugao',
        'Kalinga',
        'Mountain Province',
        'Batanes',
        'Cagayan',
        'Isabela',
        'Nueva Vizcaya',
        'Quirino'
    ],
    'MLUB':[
        'Aurora',
        'Bataan',
        'Bulacan',
        'Nueva Ecija',
        'Pampanga',
        'Tarlac',
        'Zambales',
        'Metropolitan Manila',
        'Marinduque',
        'Occidental Mindoro',
        'Oriental Mindoro',
        'Cavite',
        'Laguna',
        'Quezon',
        'Rizal',
        'Batangas',
    ],
    'CPR':[
        'Romblon',
        'Palawan',
        'Sorsogon',
        'Albay',
        'Camarines Norte',
        'Camarines Sur',
        'Catanduanes',
        'Masbate','Aklan',
        'Antique',
        'Biliran',
        'Bohol',
        'Capiz',
        'Cebu',
        'Eastern Samar',
        'Guimaras',
        'Iloilo',
        'Leyte',
        'Negros Occidental',
        'Negros Oriental',
        'Northern Samar',
        'Samar',
        'Siquijor',
        'Southern Leyte'
    ],
    'MSR': [
        'Agusan del Norte',
        'Agusan del Sur',
        'Basilan',
        'Bukidnon',
        'Camiguin',
        'Cotabato',
        'Compostela Valley',
        'Davao del Norte',
        'Davao del Sur',
        'Davao Occidental',
        'Davao Oriental',
        'Dinagat Islands',
        'Lanao del Norte',
        'Lanao del Sur',
        'Maguindanao',
        'Misamis Occidental',
        'Misamis Oriental',
        'Sarangani',
        'North Cotabato',
        'South Cotabato',
        'Sultan Kudarat',
        'Sulu',
        'Surigao del Norte',
        'Surigao del Sur',
        'Tawi-Tawi',
        'Zamboanga del Norte',
        'Zamboanga del Sur',
        'Zamboanga Sibugay'
    ]
}

# %%
list_of_regions = []
for each in df_map['province']:
    isInLoc = False
    for eachLoc in regions:
        if each in regions[eachLoc]:
            list_of_regions.append(eachLoc)
            break

# %%
df_map['island'] = list_of_regions
df_map = df_map[['island', 'province', 'city', 'geometry']]
# Out:
# C:\Users\Kyle Carlo C. Lasala\AppData\Roaming\Python\Python311\site-packages\geopandas\geodataframe.py:1543: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
choropleth_df = df_map.merge(appt_city, on='city', how='left')

# %%
choropleth_df['coords'] = choropleth_df['geometry'].apply(lambda x: x.representative_point().coords[:])
choropleth_df['coords'] = [coords[0] for coords in choropleth_df['coords']]

# %% [markdown]
# # Appointments in Luzon

# %%
ax = choropleth_df[choropleth_df.island == 'Luzon'].plot(
    figsize=(10,15), 
    column='appt', 
    legend=True,
    missing_kwds={
        "color": "lightgrey",
        "edgecolor": "grey",
        "label": "Missing values",
    }
)
# for idx, row in choropleth_df.iterrows():
#     if row['island'] == 'Luzon' and pd.notna(row['appt']):
#         ax.text(
#             row.coords[0], 
#             row.coords[1] + 0.05, 
#             s=row['city'], 
#             horizontalalignment='center', 
#             bbox={'facecolor': 'white', 'alpha':0.1, 'pad': 5, 'edgecolor':'none'},
#             fontsize=6
#         )
plt.show()

# %%
pd.notna(choropleth_df['appt'][0])
# Out:
# False

# %% [markdown]
# # Appointments in Visayas

# %%
choropleth_df
# Out:
#         island           province          city  \
# 0        Luzon               Abra       Bangued
# 1        Luzon               Abra       Boliney
# 2        Luzon               Abra         Bucay
# 3        Luzon               Abra        Bucloc
# 4        Luzon               Abra     Daguioman
# ...        ...                ...           ...
# 1642  Mindanao  Zamboanga Sibugay  Roseller Lim
# 1643  Mindanao  Zamboanga Sibugay          Siay
# 1644  Mindanao  Zamboanga Sibugay       Talusan
# 1645  Mindanao  Zamboanga Sibugay         Titay
# 1646  Mindanao  Zamboanga Sibugay      Tungawan
#
#                                                geometry  appt  \
# 0     POLYGON ((120.61134 17.49558, 120.60941 17.496...   NaN
# 1     POLYGON ((120.81400 17.34210, 120.76862 17.340...   NaN
# 2     POLYGON ((120.67766 17.45736, 120.67324 17.469...   NaN
# 3     POLYGON ((120.78922 17.44525, 120.80331 17.449...   NaN
# 4     POLYGON ((120.90749 17.41933, 120.89281 17.446...   NaN
# ...                                                 ...   ...
# 1642  MULTIPOLYGON (((122.47417 7.63000, 122.47417 7...   NaN
# 1643  MULTIPOLYGON (((122.86974 7.65476, 122.86914 7...   NaN
# 1644  MULTIPOLYGON (((122.89452 7.35639, 122.90918 7...   NaN
# 1645  POLYGON ((122.48864 7.76403, 122.48551 7.77061...   NaN
# 1646  MULTIPOLYGON (((122.23621 7.54273, 122.24481 7...   NaN
#
#                                         coords
# 0     (120.60703774508815, 17.608510017000043)
# 1        (120.87345072224, 17.380009651000137)
# 2     (120.72553595331397, 17.520785332499997)
# 3      (120.84492344457746, 17.43229007700006)
# 4      (120.94350476013321, 17.45792484350008)
# ...                                        ...
# 1642   (122.42260821920519, 7.713250160500053)
# 1643   (122.86925871591842, 7.736250000000098)
# 1644   (122.84581403348085, 7.373874903500138)
# 1645  (122.57008908203667, 7.8445250990000375)
# 1646   (122.36755948349713, 7.563435078500163)
#
# [1647 rows x 6 columns]

# %%
ax = choropleth_df[choropleth_df.island == 'Visayas'].plot(
    figsize=(15,10), 
    column='appt', 
    legend=True,
    missing_kwds={
        "color": "lightgrey",
        "edgecolor": "grey",
        "label": "Missing values",
    }
)
for idx, row in choropleth_df.iterrows():
    if row['island'] == 'Visayas' and pd.notna(row['appt']):
        ax.text(
            row.coords[0], 
            row.coords[1] + 0.05, 
            s=row['city'], 
            horizontalalignment='center', 
            bbox={'facecolor': 'white', 'alpha':0.1, 'pad': 5, 'edgecolor':'none'},
            fontsize=6
        )
plt.show()

# %% [markdown]
# # Appointments in Mindanao

# %%
ax = choropleth_df[choropleth_df.island == 'Mindanao'].plot(
    figsize=(15,10), 
    column='appt', 
    legend=True,
    missing_kwds={
        "color": "lightgrey",
        "edgecolor": "grey",
        "label": "Missing values",
    }
)
for idx, row in choropleth_df.iterrows():
    if row['island'] == 'Mindanao' and pd.notna(row['appt']):
        ax.text(
            row.coords[0], 
            row.coords[1] + 0.05, 
            s=row['city'], 
            horizontalalignment='center', 
            bbox={'facecolor': 'white', 'alpha':0.1, 'pad': 5, 'edgecolor':'none'},
            fontsize=6
        )
plt.show()
